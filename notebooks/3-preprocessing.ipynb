# %% [markdown]
# 1. Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append("../src")

from data.preprocess import run_preprocessing_pipeline

# %% [markdown]
# 2. Load Data with Target

# %%
df = pd.read_csv("../data/processed/outbreaks_with_target.csv")
print(df.shape)
df.head(3)
# Out:
# (19119, 14)
#    Year    Month       State    Location     Food Ingredient Species  \
# 0  1998  January  California  Restaurant      NaN        NaN     NaN
# 1  1998  January  California         NaN  Custard        NaN     NaN
# 2  1998  January  California  Restaurant      NaN        NaN     NaN
#
#   Serotype/Genotype Status  Illnesses  Hospitalizations  Fatalities  Severity  \
# 0               NaN    NaN         20               0.0         0.0  Moderate
# 1               NaN    NaN        112               0.0         0.0      High
# 2               NaN    NaN         35               0.0         0.0      High
#
#    Severity_code
# 0              1
# 1              2
# 2              2

# %% [markdown]
# 3. Run Preprocessing Pipeline

# %%
df_clean = run_preprocessing_pipeline(df)
# Out:
# ...
# STARTING PREPROCESSING PIPELINE
# ...
# Dropped columns: ['Ingredient', 'Serotype/Genotype', 'Hospitalizations', 'Fatalities']
#
# Removed 374 duplicate rows (19119 → 18745)
#
# Location unique values after cleaning: 13
# Location
# Restaurant                               10765
# Unknown                                   2142
# Private Home/Residence                    1980
# Catering Service                          1137
# Other                                      628
# Fast Food Restaurant                       433
# Banquet Facility                           391
# School/College/University                  357
# Grocery Store                              304
# Prison/Jail                                193
# Nursing Home/Assisted Living Facility      186
# Camp                                       119
# Religious Facility                         110
# Name: count, dtype: int64
#
# Species_Risk distribution:
# Species_Risk
# Unknown        6319
# Norovirus      5312
# ...

# %% [markdown]
# 4. Check for Remaining Missing Values

# %%
missing = df_clean.isnull().sum()
missing = missing[missing > 0]
if len(missing) == 0:
    print("No missing values remaining")
else:
    print(missing)
# Out:
# No missing values remaining

# %% [markdown]
# 5. Final Column Overview

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18745 entries, 0 to 19118
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           18745 non-null  int64
#  1   State          18745 non-null  object
#  2   Location       18745 non-null  object
#  3   Status         18745 non-null  object
#  4   Illnesses      18745 non-null  int64
#  5   Severity       18745 non-null  object
#  6   Severity_code  18745 non-null  int64
#  7   Species_Risk   18745 non-null  object
#  8   food_known     18745 non-null  int32
#  9   Food_Category  18745 non-null  object
#  10  Month_num      18745 non-null  int64
#  11  Season         18745 non-null  object
# dtypes: int32(1), int64(4), object(7)
# memory usage: 1.8+ MB

# %% [markdown]
# 6. Class Distribution After Cleaning

# %%
print(df_clean["Severity"].value_counts())
print()
print(df_clean["Severity"].value_counts(normalize=True).round(3) * 100)
# Out:
# Severity
# Low         9823
# Moderate    6128
# High        2794
# Name: count, dtype: int64
#
# Severity
# Low         52.4
# Moderate    32.7
# High        14.9
# Name: proportion, dtype: float64

# %% [markdown]
# 7. Save Cleaned Data

# %%
df_clean.to_csv("../data/processed/outbreaks_cleaned.csv", index=False)
print("Saved → data/processed/outbreaks_cleaned.csv")
print(f"Shape: {df_clean.shape}")
# Out:
# Saved → data/processed/outbreaks_cleaned.csv
# Shape: (18745, 12)
